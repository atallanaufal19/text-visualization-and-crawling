# %% [markdown]
# # Crawling Twitter Data based on **Search Keyword** Using `tweet-harvest`
# Last updated by Helmi Satria (helmisatria.com) on September 22, 2023
#
# Note: **For educational purposes only**

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [49.8 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,278 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,473 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# Crawl Data

filename = 'gibran.csv'
search_keyword = 'gibran since:2023-10-20 until:2023-11-13'
limit = 800

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sun Nov 12 23:59:49 +0000 2023  1723853132537462921
# 1    Sun Nov 12 23:59:33 +0000 2023  1723853066959483285
# 2    Sun Nov 12 23:59:29 +0000 2023  1723853052397207552
# 3    Sun Nov 12 23:59:29 +0000 2023  1723853049477648608
# 4    Sun Nov 12 23:59:11 +0000 2023  1723852973678170238
# ..                              ...                  ...
# 728  Sun Nov 12 21:58:21 +0000 2023  1723822564953215360
# 729  Sun Nov 12 21:58:07 +0000 2023  1723822507608691092
# 730  Sun Nov 12 21:58:05 +0000 2023  1723822500772200499
# 731  Sun Nov 12 21:57:42 +0000 2023  1723822402713342143
# 732  Sun Nov 12 21:56:55 +0000 2023  1723822204633395419
#
#                                              full_text  quote_count  \
# 0    @imanlagi Jokowi mo dipancing heheheh. Disaat ...            0
# 1    @CNNIndonesia Insyaallah disidang pembatalan m...            0
# 2                       @gibran_tweet Paman mana paman            0
# ...

# %%
df_text = df[['full_text']]

# %%
df_text
# Out:
#                                              full_text
# 0    @imanlagi Jokowi mo dipancing heheheh. Disaat ...
# 1    @CNNIndonesia Insyaallah disidang pembatalan m...
# 2                       @gibran_tweet Paman mana paman
# 3    @andre_rosiade Hanya bansos yg bisa menyelamat...
# 4    @tvOneNews Gibran garansi 100% bapaknya. Aman ...
# ..                                                 ...
# 728  @tvOneNews GIBRAN KALAH NGISIN NGISINI BISA DI...
# 729  @KompasTV Perubahan akan terus terjadi  Sejak ...
# 730  @hartonometroadv @hsetiyawan1979 @gibran_tweet...
# 731  @69420coineth Investing in #69420coineth is li...
# 732  Ready https://t.co/8YIMZe9p3b  Minggu Besok Se...
#
# [733 rows x 1 columns]

# %%
# !pip install wordcloud matplotlib

# %%
import nltk
from nltk.corpus import stopwords
import re  # Import the re module for regular expressions

# Download NLTK stopwords for Indonesian
nltk.download('stopwords')
stop_words_indonesian = set(stopwords.words('indonesian'))

# Kata-kata tambahan yang ingin dihapus
additional_stopwords = {'ya', 'ini', 'sih', 'nya', 'aja', 'utk', 'jd', 'krn',
                        'tdk', 'sy', 'dgn', 'karena', 'sudah', 'sdh',
                        'td', 'yg', 'ga', 'si', 'gak', 'tp'}

# Gabungkan stopwords dari NLTK dengan kata-kata tambahan yang ingin dihapus
stop_words_indonesian = stop_words_indonesian.union(additional_stopwords)

# Custom function to remove Twitter handles, links, and specified stopwords
def clean_text_custom(text):
    # Remove words containing '@' (Twitter handles)
    text = ' '.join([word for word in text.split() if '@' not in word])
    # Remove words containing 'https' (links)
    text = re.sub(r'https\S+', '', text)
    # Remove specified stopwords
    text = ' '.join([word for word in text.split() if word.lower() not in stop_words_indonesian])
    return text

# Apply the custom function to remove Twitter handles, links, and specified stopwords
df_text['cleaned_text_custom'] = df_text['full_text'].apply(clean_text_custom)
df_text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# <ipython-input-14-73c60f031ed7>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaned_text_custom'] = df_text['full_text'].apply(clean_text_custom)
#                                              full_text  \
# 0    @imanlagi Jokowi mo dipancing heheheh. Disaat ...
# 1    @CNNIndonesia Insyaallah disidang pembatalan m...
# 2                       @gibran_tweet Paman mana paman
# 3    @andre_rosiade Hanya bansos yg bisa menyelamat...
# 4    @tvOneNews Gibran garansi 100% bapaknya. Aman ...
# ..                                                 ...
# 728  @tvOneNews GIBRAN KALAH NGISIN NGISINI BISA DI...
# ...

# %%
from google.colab import files

# Simpan DataFrame ke dalam file Excel
excel_file_path = 'tweets_data_cleaned.xlsx'
df_text.to_excel(excel_file_path, index=False)

# Unduh file Excel
files.download(excel_file_path)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all the cleaned tweets into a single string
all_cleaned_text = ' '.join(df_text['cleaned_text_custom'])

# Generate the word cloud with a maximum of 50 words
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words=50).generate(all_cleaned_text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from os import path
# from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# Load the mask image
mask_gibran = np.array(Image.open("gibran.png"))  # Path to your mask image

# Generate Word Cloud with the specified mask
wordcloud = WordCloud(width=800, height=400, background_color='white', mask=mask_gibran, contour_color='red', contour_width=2, stopwords=stop_words_indonesian).generate(all_cleaned_text)
# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
